# %% [markdown]
# <a href="https://colab.research.google.com/github/quezia-cassiano/datascience/blob/main/atvd_ds0210.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install seaborn

# %%
# Importando os pacotes
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('/content/Dados-Pesquisa.csv')
# Out:
# <ipython-input-8-6cb1201a0c2c>:1: DtypeWarning: Columns (21,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   dados = pd.read_csv('/content/Dados-Pesquisa.csv')

# %%
dados.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# ...

# %%
dados.shape
# Out:
# (15620, 113)

# %%
dados.columns.to_list()
# Out:
# ['Age',
#  'AttendedBootcamp',
#  'BootcampFinish',
#  'BootcampFullJobAfter',
#  'BootcampLoanYesNo',
#  'BootcampMonthsAgo',
#  'BootcampName',
#  'BootcampPostSalary',
#  'BootcampRecommend',
#  'ChildrenNumber',
#  'CityPopulation',
#  'CodeEventBootcamp',
#  'CodeEventCoffee',
#  'CodeEventConferences',
#  'CodeEventDjangoGirls',
#  'CodeEventGameJam',
#  'CodeEventGirlDev',
#  'CodeEventHackathons',
#  'CodeEventMeetup',
#  'CodeEventNodeSchool',
#  'CodeEventNone',
#  'CodeEventOther',
#  'CodeEventRailsBridge',
#  'CodeEventRailsGirls',
#  'CodeEventStartUpWknd',
#  'CodeEventWomenCode',
#  'CodeEventWorkshop',
#  'CommuteTime',
#  'CountryCitizen',
#  'CountryLive',
#  'EmploymentField',
#  'EmploymentFieldOther',
#  'EmploymentStatus',
#  'EmploymentStatusOther',
#  'ExpectedEarning',
#  'FinanciallySupporting',
#  'Gender',
#  'HasChildren',
#  'HasDebt',
#  'HasFinancialDependents',
#  'HasHighSpdInternet',
#  'HasHomeMortgage',
#  'HasServedInMilitary',
# ...

# %%
df2 = dados.copy()

# %%
dados.isna().sum()
# Out:
# Age                      2007
# AttendedBootcamp          240
# BootcampFinish          14687
# BootcampFullJobAfter    14985
# BootcampLoanYesNo       14686
#                         ...
# ResourceW3Schools       15499
# ResourceYouTube         15499
# SchoolDegree             1941
# SchoolMajor              7170
# StudentDebtOwe          12106
# Length: 113, dtype: int64

# %%
dados.isna().sum().sum()
# Out:
# 1183948

# %%
dados.dropna(subset = ['Age'], inplace= True)

# %%
dados.isna().sum()
# Out:
# Age                         0
# AttendedBootcamp          112
# BootcampFinish          12809
# BootcampFullJobAfter    13068
# BootcampLoanYesNo       12805
#                         ...
# ResourceW3Schools       13508
# ResourceYouTube         13506
# SchoolDegree              113
# SchoolMajor              5265
# StudentDebtOwe          10121
# Length: 113, dtype: int64

# %%
print('A base de dados apresenta {} linhas e {} colunas'.format(dados.shape[0], dados.shape[1]))
# Out:
# A base de dados apresenta 13613 linhas e 113 colunas

# %%
dados.dtypes.value_counts()
# Out:
# float64    85
# object     28
# dtype: int64

# %%
dados = dados[['Age','Gender', 'JobPref', 'JobRoleInterest',
               'EmploymentField', 'JobRelocateYesNo',
               'HoursLearning', 'MoneyForLearning']]
dados
# Out:
#         Age  Gender                          JobPref  \
# 0      28.0    male                       freelance
# 1      22.0    male               work for a startup
# 2      19.0    male          start your own business
# 3      26.0  female               work for a startup
# 4      20.0  female  work for a medium-sized company
# ...     ...     ...                              ...
# 15615  39.0    male          start your own business
# 15616  27.0    male               work for a startup
# 15617  37.0    male                       freelance
# 15618  26.0    male                              NaN
# 15619  22.0  female                       freelance
#
#                  JobRoleInterest                        EmploymentField  \
# 0                            NaN      office and administrative support
# 1        Front-End Web Developer                      food and beverage
# 2                            NaN                                finance
# ...

# %%
sns.countplot(x='Gender', data=dados)
plt.title('Distribuição de Gênero')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y='JobPref', data=dados)
plt.title('Preferência de Trabalho')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Age', data=dados)
plt.title('Distribuição de Idade')
plt.show()
